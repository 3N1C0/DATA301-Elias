# %% [markdown]
# # Practice Problems Day 1
#
# ### Author: Elias Nicolas

# %% [markdown]
# ## Introduction to Machine Learning
#
# #### University of Redlands - DATA 301
# #### Prof: Joanna Bieri [joanna_bieri@redlands.edu](mailto:joanna_bieri@redlands.edu)
# #### [Class Website](https://joannabieri.com/machine_learning.html)
#
# ---
#
# **Reading:** Geron, chapter 1
#
# **How to turn this in.** In your own repository:
#
# ```bash
# git checkout -b hw/week-01
# # fill in this notebook
# git add .
# git commit -m "Day 1 homework"
# git push origin hw/week-01
# ```
#
# then open a Pull Request into `main` on GitHub. That PR is your submission.
#
# Put your name on the **Author** line at the top of this notebook before you commit.

# %% [markdown]
# ## Problem 1: Prove your environment works
#
# Run the cell below. Every line should print a version number and the last line
# should print `3.0`. Leave the output visible when you commit this one, so I can
# see it ran.

# %%
import sys
print("python      ", sys.version.split()[0])

import numpy, pandas, sklearn, matplotlib
print("numpy       ", numpy.__version__)
print("pandas      ", pandas.__version__)
print("scikit-learn", sklearn.__version__)
print("matplotlib  ", matplotlib.__version__)

import torch
print("torch       ", torch.__version__)
print("sanity check", torch.tensor([1.0, 2.0]).sum().item())
# Out:
# python       3.13.5
# numpy        2.4.0
# pandas       2.3.2
# scikit-learn 1.6.1
# matplotlib   3.10.0
# torch        2.9.1
# sanity check 3.0

# %% [markdown]
# **1b.** Did anything go wrong during setup? Write one or two sentences about what
# broke and how you fixed it. If nothing broke, say that.
#
# *When I ran the first cell I was in the wrong kernel so the libraries were not importing properly, however after consulting with Claude I fixed the issue.*

# %% [markdown]
# ## Problem 2: Prove your git workflow works
#
# Run the cell below and leave the output visible. It should show `origin` pointing
# at your own repository and `upstream` pointing at `FALL26`.

# %%
# !git remote -v
# Out:
# origin	https://github.com/MachineLearningUoR/DATA301-f26-3N1C0.git (fetch)
# origin	https://github.com/MachineLearningUoR/DATA301-f26-3N1C0.git (push)
# upstream	https://github.com/MachineLearningUoR/FALL26.git (fetch)
# upstream	https://github.com/MachineLearningUoR/FALL26.git (push)

# %% [markdown]
# **2b.** In your own words, why does this course have you work on a branch and open
# a Pull Request, instead of just editing files on `main`? One or two sentences.
#
# *It is industry standard to work on a seperate branch because as you make changes to code you are prone to risk to breaking the entire thing, operating on a seperate branch protects the master copy of the files. This means that you can run new code in the seperate branch to test out new scripts and debug, until you are ready to add those final changes to the main branch.*

# %% [markdown]
# ## Problem 3: Find a model in the wild
#
# Pick one machine learning system you personally interact with. Some possibilities:
# a streaming service's recommendations, your phone's photo search, a navigation app's
# arrival time estimate, an email spam filter, a bank's fraud alert. Pick something you
# actually use, not something from the reading.
#
# Answer all four:
#
# **3a.** What is the system predicting? Be precise. "It recommends shows" is vague.
# "Given a user and a show, it predicts the probability that the user watches more
# than five minutes" is precise.
#
# **3b.** Is this supervised, unsupervised, self-supervised, or reinforcement learning?
# Justify your answer by saying what the training data would have to look like.
#
# **3c.** If it is supervised, is it classification or regression? How do you know?
#
# **3d.** **What would it mean for this system to be wrong, and who pays for it?** A navigation app that is wrong by two minutes costs you very
# little. A fraud model that is wrong costs somebody a great deal, and it costs
# different people differently depending on which direction it is wrong in. Write a
# short paragraph.

# %% [markdown]
# **Machine Learning System: Vehicle Obstacle Detection**
#
# **3a.** Vehicle Obstacle Detection utilizes live footage via a camera and real-time precise data from sensors to quantify the threat neighboring objects present to the car. For example, my car has a bright orange light that shines if the system detects a vehicle in my blindspot

# %% [markdown]
# ## Problem 4: Why you only get one shot at the test set
#
# From the reading and from class: suppose you train a model, check it on your test
# set, get 84% accuracy, decide that is not good enough, change your model, and check
# the test set again. You repeat this fifteen times and eventually reach 91%.
#
# **4a.** Explain what is wrong with reporting 91% as this model's accuracy.
#
# **4b.** What should you have done instead?
#
# *Your answers here.*
#
#
# We spend Days 3 through 5 on this. You are not expected to have a complete answer
# yet. I want to see how you think about it before we cover it, and I will come back
# to what you wrote.

# %% [markdown]
# ## Problem 5: Reflection
#
# Two or three sentences, honestly:
#
# - What are you hoping to get out of this class?
# - What is the thing you are most worried about?
#
# I read these and I do adjust the course based on them.
#
# *Your answer here.*
